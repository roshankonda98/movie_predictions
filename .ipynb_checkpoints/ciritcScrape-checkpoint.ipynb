# %%
import requests
from bs4 import BeautifulSoup
import bs4
import json
from collections import defaultdict
import pandas as pd
from datetime import datetime
import codecs
from sklearn.preprocessing import MultiLabelBinarizer
import wget
import os

# %%
dataframe_columns = ['type','dateCreated', 'datePublished','reviewBody','url','author_type','author_name','url','content_type','movie_name','review_type','ratingValue','tomatometer']

#fields extracted from html page
review_fields = ['@type','dateCreated', 'datePublished','reviewBody','url']
author_fields = ['@type','name','url']
content_fields = ['@type','name']
rating_fields = ['@type','ratingValue','tomatometer']

#movie features
features = ['Rated','Runtime','Genre','Director','Writer','Actor','Plot','Language','Country','Poster','Production','Response']
feature_index = [2,4,5,6,7,8,9,10,11,13,22,24]
feature_dict = dict(zip(feature_index,features))

# %%
reader = codecs.getreader('utf-8')

# %%
#get page html and parse using beautiful soup
def get_page(page_num):
    URL = "https://www.rottentomatoes.com/source-337?page={}".format(page_num)
    page = requests.get(URL)

    soup = BeautifulSoup(page.content,"html.parser")
    return soup

# %%
#convert page data to pandas dataframe
def page_to_df(soup_data):
    data = []
    
    reviews = soup_data.find("script",{"type":"application/ld+json"}).contents[0] #extract unlcean review data
    reviews = reviews.strip() #remove new line characters
    reviews = json.loads(reviews) #convert to dictionary
    reviews = reviews['@graph'][1]['itemListElement'] #extract clean review data
    
    for review in reviews:
        rows = []
        for re_f in review_fields:
            rows.append(review['item'][re_f])
        for au_f in author_fields:
            rows.append(review['item']['author'][au_f])
        for co_f in content_fields:
            rows.append(review['item']['itemReviewed'][co_f])
        for ra_f in rating_fields:
            rows.append(review['item']['reviewRating'][ra_f])
        data.append(rows)
    
    return pd.DataFrame(data,columns = dataframe_columns)

# %%
def get_movie_id(movie):
    res = ia.search_move(movie)
    for r in res:
        if r['title'] == Movie:
            return r['']

# %%
#loop through rotten tomatoes pages and get data
all_reviews = []
total_review_pages = 378
for page in range(1,total_review_pages+1):
    try:
        all_reviews.append(page_to_df(get_page(page)))
    except:
        pass

# %%
def call_api(movie,year):
    url = "http://www.omdbapi.com/?apikey=69c24e49&t={}&y={}&type=movie".format(movie,year)
    response = requests.get(url).json()
    return response

# %%
def call_api_image(movie,year):
    url = "http://img.omdbapi.com/?apikey=&t={}&y={}".format(movie,year)

# %%
#account for writer vs writers, actor vs actors in api responses etc.
def data_reformat(res):
    curr = []
    for f in features:
        if(f in res.keys()):
            curr.append(res[f])
        elif(f+"s" in res.keys()):
            curr.append(res[f+"s"])
        else:
            curr.append("N/A")
    return dict(zip(features,curr))

# %%
#compile scraped dataframes into a single frame and export as csv
total_reviews = pd.concat(all_reviews)
total_reviews.to_csv("total_reviews.csv",index = False)

# %%
data = pd.read_csv('total_reviews.csv')

# %%
#get the year the movie came out using the strptime function
data['year'] = data['dateCreated'].apply(lambda date: datetime.strptime(date,'%b %d, %Y').year)

# %%
#get additional features from omdb api 
extra_data = []
for n in range(len(data)):
    extra_data.append(
        call_api(
            data['movie_name'][n],
            data['year'][n]
        )
    )
    print(n,end='')
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...

# %%
reformat_data = []
for ed in extra_data:
    reformat_data.append(data_reformat(ed))

# %%
#make list of dictionaries into a pandas dataframe
feature_df = pd.DataFrame(reformat_data)

# %%
#combine total data and feature data
data_total = pd.concat([data,feature_df],axis=1)

# %%
data_total
# Out:
#          type   dateCreated datePublished  \
# 0      Review  Jul 23, 2021  Jul 23, 2021
# 1      Review  Jul 22, 2021  Jul 22, 2021
# 2      Review  Jul 22, 2021  Jul 22, 2021
# 3      Review  Jul 22, 2021  Jul 22, 2021
# 4      Review  Jul 22, 2021  Jul 22, 2021
# ...       ...           ...           ...
# 13545  Review   Jan 1, 2000   Jan 1, 2000
# 13546  Review   Jan 1, 2000   Jan 1, 2000
# 13547  Review   Jan 1, 2000   Jan 1, 2000
# 13548  Review   Jan 1, 2000   Jan 1, 2000
# 13549  Review   Jan 1, 2000   Jan 1, 2000
#
#                                               reviewBody  \
# 0      Are we meant to recoil from sharks or care for...
# 1      The film excels when it harnesses the wistful ...
# 2      Shyamalan's fluid filmmaking style, outstandin...
# 3      Wignot layers images, video and - most importa...
# 4      Often as thorny as its subject but also oddly ...
# ...                                                  ...
# 13545  This would-be spicy film has been made blandly...
# 13546  Don't bother to hang around for the outtakes. ...
# 13547  For all its clever notions, Book of Shadows of...
# 13548  Chill Factor has no aspirations to be anything...
# 13549                                                NaN
#
#                                                      url author_type  \
# 0      https://www.nytimes.com/2021/07/23/movies/play...      Person
# 1      https://www.nytimes.com/2021/07/22/movies/all-...      Person
# 2      https://www.nytimes.com/2021/07/22/movies/old-...      Person
# 3      https://www.nytimes.com/2021/07/22/movies/aile...      Person
# 4      https://www.nytimes.com/2021/07/22/movies/char...      Person
# ...                                                  ...         ...
# 13545                                                NaN      Person
# 13546  http://movies.nytimes.com/movie/review?res=940...      Person
# 13547                                                NaN      Person
# 13548                                                NaN      Person
# 13549                                                NaN      Person
#
#                author_name                                              url.1  \
# 0        Natalia Winkelman  https://www.rottentomatoes.com/critic/natalia-...
# 1         Isabelia Herrera  https://www.rottentomatoes.com/critic/isabelia...
# 2              Glenn Kenny  https://www.rottentomatoes.com/critic/glenn-kenny
# 3              Gia Kourlas  https://www.rottentomatoes.com/critic/gia-kourlas
# 4              Lena Wilson  https://www.rottentomatoes.com/critic/lena-wilson
# ...                    ...                                                ...
# 13545       Elvis Mitchell  https://www.rottentomatoes.com/critic/elvis-mi...
# 13546  Lawrence Van Gelder  https://www.rottentomatoes.com/critic/lawrence...
# 13547       Stephen Holden  https://www.rottentomatoes.com/critic/stephen-...
# 13548       Stephen Holden  https://www.rottentomatoes.com/critic/stephen-...
# 13549         Janet Maslin  https://www.rottentomatoes.com/critic/janet-ma...
#
#       content_type                                         movie_name  ...  \
# 0            Movie                                Playing With Sharks  ...
# 1            Movie  All the Streets Are Silent: The Convergence of...  ...
# 2            Movie                                                Old  ...
# 3            Movie                                              Ailey  ...
# 4            Movie                                          Charlatan  ...
# ...            ...                                                ...  ...
# 13545        Movie                                       Woman on Top  ...
# 13546        Movie                                         Dirty Work  ...
# 13547        Movie                     Book of Shadows: Blair Witch 2  ...
# 13548        Movie                                       Chill Factor  ...
# 13549        Movie                                    Best Laid Plans  ...
#
#                  Director                                             Writer  \
# 0            Sally Aitken                                       Sally Aitken
# 1            Jeremy Elkin                           Dana Brown, Jeremy Elkin
# 2      M. Night Shyamalan  M. Night Shyamalan, Pierre-Oscar Lévy, Frederi...
# 3           Jamila Wignot                                                N/A
# 4            Colin Bowles                              Colin Bowles (Writer)
# ...                   ...                                                ...
# 13545         Fina Torres                                         Vera Blasi
# 13546                 N/A                                                N/A
# 13547       Joe Berlinger         Daniel Myrick, Eduardo Sánchez, Dick Beebe
# 13548                 N/A                                                N/A
# 13549                 N/A                                                N/A
#
#                                                    Actor  \
# 0                                         Valerie Taylor
# 1                  Rosario Dawson, Leo Fitzpatrick, Moby
# 2         Gael García Bernal, Vicky Krieps, Rufus Sewell
# 3             Judith Jamison, Alvin Ailey, Bill T. Jones
# 4      Larissa White, Haley Evans, Courtney Rikki Gre...
# ...                                                  ...
# 13545  Penélope Cruz, Murilo Benício, Harold Perrinea...
# 13546                                                N/A
# 13547  Jeffrey Donovan, Stephen Barker Turner, Erica ...
# 13548                                                N/A
# 13549                                                N/A
#
#                                                     Plot             Language  \
# 0      Pioneering scuba diver Valerie Taylor, who has...              English
# 1                                              Trailer 1              English
# 2      A thriller about a family on a tropical holida...              English
# 3      An immersive portrait of dance pioneer Alvin A...              English
# 4      A bright law student hosts a blissful weekend ...              English
# ...                                                  ...                  ...
# 13545  Brazilian chef Isabella Oliveira moves to San ...  English, Portuguese
# 13546                                                N/A                  N/A
# 13547  A group of tourists arrives in Burkittsville, ...      English, German
# 13548                                                N/A                  N/A
# 13549                                                N/A                  N/A
#
#              Country                                             Poster  \
# 0      United States  https://m.media-amazon.com/images/M/MV5BNzFhZG...
# 1      United States  https://m.media-amazon.com/images/M/MV5BMTExMm...
# 2      United States  https://m.media-amazon.com/images/M/MV5BZGMxYm...
# 3      United States  https://m.media-amazon.com/images/M/MV5BZDAzOW...
# 4                USA                                                N/A
# ...              ...                                                ...
# 13545            USA  https://m.media-amazon.com/images/M/MV5BODc2ND...
# 13546            N/A                                                N/A
# 13547  United States  https://m.media-amazon.com/images/M/MV5BY2YzNz...
# 13548            N/A                                                N/A
# 13549            N/A                                                N/A
#
#                                        Production Response      imdbID
# 0                                             N/A     True  tt11226258
# 1                                             N/A     True  tt12825680
# 2      Universal Pictures, Blinding Edge Pictures     True  tt10954652
# 3                                             N/A     True  tt13622084
# 4                                             N/A     True  tt14361772
# ...                                           ...      ...         ...
# 13545                             Fox Searchlight     True   tt0206420
# 13546                                         N/A    False         N/A
# 13547  Artisan Entertainment, Haxan Entertainment     True   tt0229260
# 13548                                         N/A    False         N/A
# 13549                                         N/A    False         N/A
#
# [13550 rows x 27 columns]

# %%
#filter only english movies to keep the data uniform
data_total_english = data_total[data_total['Language'].str.contains('English')]

# %%
#filter to only studio movies to further enforce uniformity and simplify the problem 
data_total_english_studio = data_total_english[data_total_english['Production'] != 'N/A']

# %%
data_total_english_studio = data_total_english_studio.reset_index(drop = True)

# %%
data_total_english_studio.to_csv("data_total_english_studio.csv",index = False)

# %%
data_total_english_studio = pd.read_csv("data_total_english_studio.csv")

# %%
#download all posters, remove ? and / from name to stop errors
for n in range(len(data_total_english_studio)):
    if not data_total_english_studio['Poster'][n] == "N/A":
        try:
            wget.download(data_total_english_studio['Poster'][n],out = "poster/{}.jpg".format(data_total_english_studio['movie_name'][n].replace("?","").replace("/","")))
        except:
            pass
# Out:
# 100% [..............................................................................] 32395 / 32395

# %%
#remove empty poster images
for file in os.listdir("poster"):
    if(not ".jpg" in file):
        os.remove("poster/{}".format(file))

# %%
#remove any rows where there is a N/A
for col in ['Rated','Runtime','Genre','Director','Writer','Actor','Plot','Country']:
    data_total_english_studio = data_total_english_studio[data_total_english_studio[col] != "N/A"]

# %%
#check which movies do not have a poster
poster = []
posters = [x.replace(".jpg","") for x in os.listdir("C:/Users/16789/Documents/MovieProject/poster")]
for m in data_total_english_studio['movie_name']:
    if(not m.replace("?","").replace("/","") in posters):
        poster.append(False)
    else:
        poster.append(True)
data_total_english_studio['poster'] = poster

# %%
#only keep movies with poster
data_total_english_studio = data_total_english_studio[data_total_english_studio['poster'] == True]

# %%
#save as csv
data_total_english_studio.to_csv("data_total_english_studio_final.csv",index = False)
